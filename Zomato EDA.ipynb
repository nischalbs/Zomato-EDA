# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plot

# %%
df=pd.read_csv(r"C:\Users\91831\Desktop\zomato.csv")
df.head(5)
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
df.shape
# Out:
# (51717, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
listed_in_city=df["listed_in(city)"]
listed_in_city
# Out:
# 0        Banashankari
# 1        Banashankari
# 2        Banashankari
# 3        Banashankari
# 4        Banashankari
#              ...
# 51712      Whitefield
# 51713      Whitefield
# 51714      Whitefield
# 51715      Whitefield
# 51716      Whitefield
# Name: listed_in(city), Length: 51717, dtype: object

# %%
df_1=df['listed_in(city)'].value_counts()
df_1=pd.DataFrame(df_1)
df_1.shape
# Out:
# (30, 1)

# %%
listed_in_city=df["listed_in(city)"].unique()
len(listed_in_city)
# Out:
# 30

# %%
df_2=df['location'].value_counts()
df_2=pd.DataFrame(df_2)
df_2
# Out:
#                        location
# BTM                        5124
# HSR                        2523
# Koramangala 5th Block      2504
# JP Nagar                   2235
# Whitefield                 2144
# ...                         ...
# West Bangalore                6
# Yelahanka                     6
# Jakkur                        3
# Rajarajeshwari Nagar          2
# Peenya                        1
#
# [93 rows x 1 columns]

# %%
location=df["location"].unique()
len(location)
# Out:
# 94

# %%
a=[]
for i in location:
    if i not in df_1:
        a.append(i)
a
# Out:
# ['Banashankari',
#  'Basavanagudi',
#  'Mysore Road',
#  'Jayanagar',
#  'Kumaraswamy Layout',
#  'Rajarajeshwari Nagar',
#  'Vijay Nagar',
#  'Uttarahalli',
#  'JP Nagar',
#  'South Bangalore',
#  'City Market',
#  'Nagarbhavi',
#  'Bannerghatta Road',
#  'BTM',
#  'Kanakapura Road',
#  'Bommanahalli',
#  nan,
#  'CV Raman Nagar',
#  'Electronic City',
#  'HSR',
#  'Marathahalli',
#  'Sarjapur Road',
#  'Wilson Garden',
#  'Shanti Nagar',
#  'Koramangala 5th Block',
#  'Koramangala 8th Block',
#  'Richmond Road',
#  'Koramangala 7th Block',
#  'Jalahalli',
#  'Koramangala 4th Block',
#  'Bellandur',
#  'Whitefield',
#  'East Bangalore',
#  'Old Airport Road',
#  'Indiranagar',
#  'Koramangala 1st Block',
#  'Frazer Town',
#  'RT Nagar',
#  'MG Road',
#  'Brigade Road',
#  'Lavelle Road',
#  'Church Street',
#  'Ulsoor',
#  'Residency Road',
#  'Shivajinagar',
#  'Infantry Road',
#  'St. Marks Road',
#  'Cunningham Road',
#  'Race Course Road',
#  'Commercial Street',
# ...

# %%
b=[]
for i in df_1:
    if i not in location:
        a.append(i)
b
# Out:
# []

# %% [markdown]
# ### We drop the listed in cities column as we can see all the unique values in listed in cities are already in location column

# %%
Train=df.drop(['listed_in(city)'], axis=1)

# %%
df_2.plot.bar(figsize=(100,50),rot=0)
plot.title('Frequency Distribution of orders with respect to Area', fontsize=100)
plot.show(block=True)

# %% [markdown]
# ### Inference from the above Graph - Most of the orders are from BTM,HSR and kormangala

# %%
online_order=df["online_order"]
online_order
# Out:
# 0        Yes
# 1        Yes
# 2        Yes
# 3         No
# 4         No
#         ...
# 51712     No
# 51713     No
# 51714     No
# 51715     No
# 51716     No
# Name: online_order, Length: 51717, dtype: object

# %%
online_order=pd.get_dummies(online_order)
online_order
# Out:
#        No  Yes
# 0       0    1
# 1       0    1
# 2       0    1
# 3       1    0
# 4       1    0
# ...    ..  ...
# 51712   1    0
# 51713   1    0
# 51714   1    0
# 51715   1    0
# 51716   1    0
#
# [51717 rows x 2 columns]

# %%
Total=online_order.sum()
Total
# Out:
# No     21273
# Yes    30444
# dtype: int64

# %%
Total.plot.bar(figsize=(10,5),rot=0, title="online orders")
plot.show(block=True)

# %% [markdown]
# ### Inference 58% of the people order food online

# %%
online_order=online_order.drop(['No'], axis=1)
yes=((online_order.sum())/51717)*100

# %%
print("Percentage of people ordering online",yes)
# Out:
# Percentage of people ordering online Yes    58.866524
# dtype: float64

# %%
book_table=df["book_table"]
book_table
# Out:
# 0        Yes
# 1         No
# 2         No
# 3         No
# 4         No
#         ...
# 51712     No
# 51713     No
# 51714     No
# 51715    Yes
# 51716     No
# Name: book_table, Length: 51717, dtype: object

# %%
book_table=pd.get_dummies(book_table)
book_table
# Out:
#        No  Yes
# 0       0    1
# 1       1    0
# 2       1    0
# 3       1    0
# 4       1    0
# ...    ..  ...
# 51712   1    0
# 51713   1    0
# 51714   1    0
# 51715   0    1
# 51716   1    0
#
# [51717 rows x 2 columns]

# %%
Total_=book_table.sum()
Total_
# Out:
# No     45268
# Yes     6449
# dtype: int64

# %%
Total_.plot.bar(figsize=(10,5),rot=0, title="Table Booking")
plot.show(block=True)

# %% [markdown]
# ### Inference 12.46% people book tables

# %%
book_table=book_table.drop(['No'], axis=1)
yes_=(((book_table.sum())/51717)*100)

# %%
print("Percentage of people Booking Tables",yes_)
# Out:
# Percentage of people Booking Tables Yes    12.469787
# dtype: float64

# %% [markdown]
# ### There are Records of 8792 Food joints in The Dataset

# %%
Name_uiq=df["name"].unique()
len(Name_uiq)
# Out:
# 8792

# %%
Rating= Train['rate'].str[:3]
Rating=pd.DataFrame(Rating)
Rating
# Out:
#       rate
# 0      4.1
# 1      4.1
# 2      3.8
# 3      3.7
# 4      3.8
# ...    ...
# 51712  3.6
# 51713  NaN
# 51714  NaN
# 51715  4.3
# 51716  3.4
#
# [51717 rows x 1 columns]

# %%
Rating.rename(columns = {'rate':'Rating'}, inplace = True)
Rating
# Out:
#       Rating
# 0        4.1
# 1        4.1
# 2        3.8
# 3        3.7
# 4        3.8
# ...      ...
# 51712    3.6
# 51713    NaN
# 51714    NaN
# 51715    4.3
# 51716    3.4
#
# [51717 rows x 1 columns]

# %%
Train = pd.concat([Train, Rating], axis="columns",join="inner")

# %%
online_order=Train["online_order"]

# %%
online_order=pd.get_dummies(online_order)

# %%
online_order=online_order.drop(['No'], axis=1)

# %%
Train = pd.concat([Train, online_order], axis="columns",join="inner")
Train.rename(columns = {'Yes':'online_order_'}, inplace = True)

# %%
Train=Train.drop(['online_order'], axis=1)

# %%
book_table=Train["book_table"]

# %%
book_table=pd.get_dummies(book_table)

# %%
book_table=book_table.drop(['No'], axis=1)

# %%
Train = pd.concat([Train,book_table], axis="columns",join="inner")
Train.rename(columns = {'Yes':'book_table_'}, inplace = True)

# %%
Train=Train.drop(['book_table'], axis=1)

# %%
Train = Train.dropna()
Train.shape
# Out:
# (23193, 17)

# %%
Train['approx_cost(for two people)'] = Train['approx_cost(for two people)'].str.replace(',','')

# %%
Train["approx_cost(for two people)"] = Train["approx_cost(for two people)"].astype(str).astype(int)

# %%
df_3=df['listed_in(type)'].value_counts()
df_3=pd.DataFrame(df_3)
df_3
# Out:
#                     listed_in(type)
# Delivery                      25942
# Dine-out                      17779
# Desserts                       3593
# Cafes                          1723
# Drinks & nightlife             1101
# Buffet                          882
# Pubs and bars                   697

# %%
df_3.plot.bar(figsize=(120,50),rot=0, title="Type of serve",fontsize=100)
plot.title('Frequency Distribution of orders with respect to Service', fontsize=100)
plot.show(block=True)

# %%
Hotel=Train["name"].unique()
len(Hotel)
# Out:
# 3159

# %%
Item=Train["menu_item"].unique()
len(Item)
# Out:
# 5026

# %%
Sevice=Train["listed_in(type)"]

# %%
Sevice=pd.get_dummies(Sevice)

# %%
Train = pd.concat([Train, Sevice], axis="columns",join="inner")
Train.shape
# Out:
# (23193, 24)

# %%
Phone=Train["phone"]
count=Phone.unique()
len(count)
# Out:
# 6809

# %%
Phone=pd.Series(Phone)

# %%
Toll_Free=[itm[0] for itm in Phone.str.findall('^[080].*') if len(itm)>0]
Toll_Free=pd.DataFrame(Toll_Free)
Toll_Free.value_counts()
# Out:
# 080 33994444        57
# 080 49994999        33
# 080 39883988        30
# 080 22119898        28
# 080 43334321        28
#                     ..
# 080 41265000         1
# 080 41261947         1
# 080 41256483\r       1
# 080 41255175\r       1
# 0948 1212929\r\r     1
# Length: 2926, dtype: int64

# %% [markdown]
# # Most number of orders by 080 33994444

# %%
Mobile=[itm[0] for itm in Phone.str.findall('^[+91].*') if len(itm)>0]
Mobile=pd.DataFrame(Mobile)
Mobile.value_counts()
# Out:
# +91 7700020020            54
# +91 8880141000            35
# +91 7676764422            32
# +91 7710055553            32
# +91 9481511911            29
#                           ..
# +91 9844352310\r\r         1
# +91 9590895055\r\r\r\r     1
# +91 9844111020\r           1
# +91 9844109488             1
# 18602660010                1
# Length: 3753, dtype: int64

# %% [markdown]
# # Most number of orders by  +91 7700020020

# %%
Train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23193 entries, 0 to 51715
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          23193 non-null  object
#  1   address                      23193 non-null  object
#  2   name                         23193 non-null  object
#  3   rate                         23193 non-null  object
#  4   votes                        23193 non-null  int64
#  5   phone                        23193 non-null  object
#  6   location                     23193 non-null  object
#  7   rest_type                    23193 non-null  object
#  8   dish_liked                   23193 non-null  object
#  9   cuisines                     23193 non-null  object
#  10  approx_cost(for two people)  23193 non-null  int32
#  11  reviews_list                 23193 non-null  object
#  12  menu_item                    23193 non-null  object
# ...

# %%
Train.describe()
# Out:
#               votes  approx_cost(for two people)  online_order_   book_table_  \
# count  23193.000000                 23193.000000   23193.000000  23193.000000
# mean     601.074462                   755.904368       0.705299      0.263959
# std     1114.854301                   521.448320       0.455918      0.440787
# min        0.000000                    40.000000       0.000000      0.000000
# 25%      101.000000                   400.000000       0.000000      0.000000
# 50%      221.000000                   600.000000       1.000000      0.000000
# 75%      586.000000                  1000.000000       1.000000      1.000000
# max    16832.000000                  6000.000000       1.000000      1.000000
#
#              Buffet         Cafes      Delivery      Desserts      Dine-out  \
# count  23193.000000  23193.000000  23193.000000  23193.000000  23193.000000
# mean       0.032855      0.045143      0.458112      0.057474      0.345320
# ...

# %%
Train.rename(columns = {'approx_cost(for two people)':'Cost_for_2'}, inplace = True)

# %%
Train.columns
# Out:
# Index(['url', 'address', 'name', 'rate', 'votes', 'phone', 'location',
#        'rest_type', 'dish_liked', 'cuisines', 'Cost_for_2', 'reviews_list',
#        'menu_item', 'listed_in(type)', 'Rating', 'online_order_',
#        'book_table_', 'Buffet', 'Cafes', 'Delivery', 'Desserts', 'Dine-out',
#        'Drinks & nightlife', 'Pubs and bars'],
#       dtype='object')

# %%
Train = Train[(Train.Rating != 'NEW') & (Train.Rating != '-')]

# %%
Rating=Train['Rating']
Rating.value_counts()
# Out:
# 3.9    3238
# 4.0    2860
# 4.1    2786
# 3.8    2473
# 4.2    2097
# 4.3    1671
# 3.7    1639
# 4.4    1123
# 3.6     875
# 4.5     630
# 3.5     482
# 3.4     351
# 2.8     315
# 2.9     309
# 3.1     307
# 4.6     294
# 3.0     291
# 3.2     249
# 3.3     218
# 2.7     190
# 4.7     167
# 2.6     138
# 4.8      66
# 2.5      57
# 4.9      55
# 2.4      54
# 2.3      45
# 2.2      26
# 2.1      24
# 2.0      11
# 1.8       5
# Name: Rating, dtype: int64

# %%
Train['Rating'] = Train['Rating'].astype(str).astype(float)

# %%
Select=Train.query(" Cost_for_2 <600 and Rating >4")
Select
# Out:
#                                                      url  \
# 9      https://www.zomato.com/bangalore/smacznego-ban...
# 10     https://www.zomato.com/bangalore/caf%C3%A9-dow...
# 12     https://www.zomato.com/bangalore/the-coffee-sh...
# 34     https://www.zomato.com/bangalore/faasos-banash...
# 52     https://www.zomato.com/bangalore/corner-house-...
# ...                                                  ...
# 51311  https://www.zomato.com/bangalore/mooch-marod-w...
# 51312  https://www.zomato.com/bangalore/biryani-kitch...
# 51313  https://www.zomato.com/bangalore/stoner-whitef...
# 51345  https://www.zomato.com/bangalore/the-wok-shop-...
# 51376  https://www.zomato.com/bangalore/nu-tree-1-whi...
#
#                                                  address  \
# 9      2470, 21 Main Road, 25th Cross, Banashankari, ...
# 10     12,29 Near PES University Back Gate, D'Souza N...
# 12         6th Block, 3rd Stage, Banashankari, Bangalore
# ...

# %%
Goal=Select['name']
Budget=Goal.value_counts()
Budget=pd.DataFrame(Budget)
Budget
# Out:
#                                                     name
# Corner House Ice Cream                                52
# Natural Ice Cream                                     40
# Leon Grill                                            38
# Stoner                                                38
# 99 Pancakes                                           33
# ...                                                  ...
# Brahmin's Coffee Bar                                   1
# Hotel Annapoorna                                       1
# Bombay Chowpaty Kulfi                                  1
# Shivaji Military Hotel                                 1
# Moto Store & CafÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ...     1
#
# [362 rows x 1 columns]

# %% [markdown]
# # There are 362 Food Joints with 4+ rating and cost less than 600 for 2

# %%
ax = Budget.plot.line(figsize=(20,7))
